# %%
dbutils.help()

# %% [markdown]
# # Utilities

# %%
dbutils.widgets.help()

# %%
dbutils.widgets.combobox("top_n_records", defaultValue="1", choices=["1", "2", "3", "4", "5"], label="Top N Records")

# %%
dbutils.widgets.get("top_n_records")

# %%
dbutils.widgets.dropdown(
    "environment",
    defaultValue="Development",
    choices=["Development", "Tresting", "Pre production"],
    label="Evn Type",
)

# %%
dbutils.widgets.multiselect(name="user_input", defaultValue = "2G", choices=["2G", "3G", "5G"], label="Technology")

# %%
#dbutils.widgets.remove("user_import")
dbutils.widgets.removeAll()
