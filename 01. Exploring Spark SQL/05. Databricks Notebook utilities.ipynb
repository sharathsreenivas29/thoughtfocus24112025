# %%
dbutils.notebook.help()

# %%
message = dbutils.notebook.run("./Childnotebook", timeout_seconds=30)
message

# %%
exdcute_status = dbutils.notebook.run("./Childnotebook", timeout_seconds=100, arguments={"environment": "Testing"})
exdcute_status
